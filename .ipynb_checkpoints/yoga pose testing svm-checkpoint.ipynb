# %% [markdown]
# # Landmark detection

# %%
# !pip install mediapipe opencv-python pandas scikit-learn
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: mediapipe in /usr/local/lib/python3.9/site-packages (0.8.8)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/site-packages (4.5.3.56)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/site-packages (1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/site-packages (from mediapipe) (3.4.3)
# Requirement already satisfied: protobuf>=3.11.4 in /usr/local/lib/python3.9/site-packages (from mediapipe) (3.18.1)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.9/site-packages (from mediapipe) (4.5.3.56)
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/site-packages (from mediapipe) (0.37.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.9/site-packages (from mediapipe) (21.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/site-packages (from mediapipe) (1.21.2)
# Requirement already satisfied: six in /usr/local/lib/python3.9/site-packages (from mediapipe) (1.16.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.9/site-packages (from mediapipe) (0.14.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn) (1.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn) (3.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/site-packages (from matplotlib->mediapipe) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/site-packages (from matplotlib->mediapipe) (8.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/site-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/site-packages (from matplotlib->mediapipe) (0.10.0)
# WARNING: You are using pip version 21.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import mediapipe as mp
import cv2
import csv
import os
import numpy as np
from matplotlib import pyplot as plt

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_pose = mp.solutions.pose # Mediapipe Solutions

# %%
class_name = "Downdog"
imgs = []
path = "yoga pose dataset/TRAIN/downdog"
for f in os.listdir(path):
    imgs.append(path+f)
    
error=0
errors=[]

for i in range (77,len(imgs)-1):
    img = cv2.imread(imgs[i])
    #plt.figure(figsize = [10,10])
    #plt.title("Sample Image");plt.axis('off');plt.imshow(img[:,:,::-1]);plt.show()

    try:

        with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                results = holistic.process(img)
                x = len(results.pose_landmarks.landmark)

                #for i in range (0,x):
                 #   print(mp_holistic.PoseLandmark(i).name)
                 #   print(results.pose_landmarks.landmark[mp_holistic.PoseLandmark(i).value])

                pose = results.pose_landmarks.landmark
                pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
                pose_row.insert(0,class_name)

                with open('pose.csv', mode='a', newline='') as f:
                    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                    csv_writer.writerow(pose_row) 
    except AttributeError: 
                print(imgs[i])
                error+=1
                errors.append(imgs[i])
# Out:
# dataset/arabesque ballet/arabesque ballet_0_5758.jpeg
# dataset/arabesque ballet/arabesque ballet_0_1259.jpeg
# dataset/arabesque ballet/arabesque ballet_0_5076.jpeg
# dataset/arabesque ballet/arabesque ballet_0_6953.jpeg
# dataset/arabesque ballet/arabesque ballet_0_2896.jpeg
# dataset/arabesque ballet/arabesque ballet_0_6466.jpeg
# dataset/arabesque ballet/arabesque ballet_0_9910.jpeg
# dataset/arabesque ballet/arabesque ballet_0_2521.jpeg
# dataset/arabesque ballet/arabesque ballet_0_6958.jpeg
# dataset/arabesque ballet/arabesque ballet_0_9265.jpeg
# dataset/arabesque ballet/arabesque ballet_0_7406.jpeg
# dataset/arabesque ballet/arabesque ballet_0_4343.jpeg
# dataset/arabesque ballet/arabesque ballet_0_5378.jpeg
# dataset/arabesque ballet/arabesque ballet_0_2452.jpeg
# dataset/arabesque ballet/arabesque ballet_0_506.jpeg
# dataset/arabesque ballet/arabesque ballet_0_1229.jpeg
# dataset/arabesque ballet/arabesque ballet_0_5905.jpeg
# dataset/arabesque ballet/arabesque ballet_0_3700.jpeg
# dataset/arabesque ballet/arabesque ballet_0_9419.jpeg
# dataset/arabesque ballet/arabesque ballet_0_7796.jpeg
# dataset/arabesque ballet/arabesque ballet_0_8619.jpeg
# dataset/arabesque ballet/arabesque ballet_0_7850.jpeg
# dataset/arabesque ballet/arabesque ballet_0_5973.jpeg
# dataset/arabesque ballet/arabesque ballet_0_9569.jpeg
# dataset/arabesque ballet/arabesque ballet_0_4658.jpeg
# dataset/arabesque ballet/arabesque ballet_0_2299.jpeg
# dataset/arabesque ballet/arabesque ballet_0_1231.jpeg
# dataset/arabesque ballet/arabesque ballet_0_1163.jpeg
# dataset/arabesque ballet/arabesque ballet_0_3670.jpeg
# dataset/arabesque ballet/arabesque ballet_0_1319.jpeg
# dataset/arabesque ballet/arabesque ballet_0_1790.jpeg
# dataset/arabesque ballet/arabesque ballet_0_3502.jpeg
# dataset/arabesque ballet/arabesque ballet_0_4228.jpeg
# dataset/arabesque ballet/arabesque ballet_0_7278.jpeg
# dataset/arabesque ballet/arabesque ballet_0_3104.jpeg
# dataset/arabesque ballet/arabesque ballet_0_7203.jpeg
# dataset/arabesque ballet/arabesque ballet_0_2144.jpeg
# dataset/arabesque ballet/arabesque ballet_0_9564.jpeg
# dataset/arabesque ballet/arabesque ballet_0_7370.jpeg
# dataset/arabesque ballet/arabesque ballet_0_6998.jpeg
# dataset/arabesque ballet/arabesque ballet_0_9179.jpeg
# dataset/arabesque ballet/arabesque ballet_0_4862.jpeg
# dataset/arabesque ballet/arabesque ballet_0_4869.jpeg
# dataset/arabesque ballet/arabesque ballet_0_4347.jpeg
# dataset/arabesque ballet/arabesque ballet_0_7496.jpeg
# dataset/arabesque ballet/arabesque ballet_0_5038.jpeg
# dataset/arabesque ballet/arabesque ballet_0_5262.jpeg
# dataset/arabesque ballet/arabesque ballet_0_4189.jpeg
# dataset/arabesque ballet/arabesque ballet_0_1333.jpeg
# dataset/arabesque ballet/arabesque ballet_0_7727.jpeg
# dataset/arabesque ballet/arabesque ballet_0_9693.jpeg
# dataset/arabesque ballet/arabesque ballet_0_2564.jpeg
# dataset/arabesque ballet/arabesque ballet_0_3231.jpeg
# dataset/arabesque ballet/arabesque ballet_0_6766.jpeg
# dataset/arabesque ballet/arabesque ballet_0_5078.jpeg
# dataset/arabesque ballet/arabesque ballet_0_6195.jpeg
# dataset/arabesque ballet/arabesque ballet_0_5296.jpeg
# dataset/arabesque ballet/arabesque ballet_0_8959.jpeg

# %%
class_name = "Demi Plie"
imgs2 = []
path = "dataset/demi plie/"
for f in os.listdir(path):
    imgs2.append(path+f)
    
error=0
errors=[]

for i in range (77,len(imgs2)-1):
    img = cv2.imread(imgs2[i])
    #plt.figure(figsize = [10,10])
    #plt.title("Sample Image");plt.axis('off');plt.imshow(img[:,:,::-1]);plt.show()

    try:

        with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                results = holistic.process(img)
                x = len(results.pose_landmarks.landmark)

                #for i in range (0,x):
                 #   print(mp_holistic.PoseLandmark(i).name)
                 #   print(results.pose_landmarks.landmark[mp_holistic.PoseLandmark(i).value])

                pose = results.pose_landmarks.landmark
                pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
                pose_row.insert(0,class_name)

                with open('pose.csv', mode='a', newline='') as f:
                    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                    csv_writer.writerow(pose_row) 
    except AttributeError: 
                print(imgs2[i])
                error+=1
                errors.append(imgs2[i])
# Out:
# dataset/demi plie/first position ballet_0_6424.jpeg
# dataset/demi plie/first position ballet_0_2902.jpeg
# dataset/demi plie/first position ballet_0_4747.jpeg
# dataset/demi plie/first position ballet_0_2851.jpeg
# dataset/demi plie/first position ballet_0_9227.jpeg
# dataset/demi plie/first position ballet_0_5341.jpeg
# dataset/demi plie/first position ballet_0_8622.jpeg
# dataset/demi plie/first position ballet_0_892.jpeg
# dataset/demi plie/first position ballet_0_7703.jpeg
# dataset/demi plie/first position ballet_0_851.jpeg
# dataset/demi plie/first position ballet_0_8161.jpeg
# dataset/demi plie/first position ballet_0_7060.jpeg
# dataset/demi plie/first position ballet_0_2171.jpeg
# dataset/demi plie/first position ballet_0_7237.jpeg
# dataset/demi plie/first position ballet_0_8697.jpeg
# dataset/demi plie/first position ballet_0_1623.jpeg
# dataset/demi plie/first position ballet_0_1204.jpeg
# dataset/demi plie/first position ballet_0_5744.jpeg
# dataset/demi plie/first position ballet_0_4591.jpeg
# dataset/demi plie/first position ballet_0_9486.jpeg
# dataset/demi plie/first position ballet_0_9652.jpeg
# dataset/demi plie/first position ballet_0_8653.jpeg
# dataset/demi plie/first position ballet_0_601.jpeg
# dataset/demi plie/first position ballet_0_4294.jpeg
# dataset/demi plie/first position ballet_0_695.jpeg
# dataset/demi plie/first position ballet_0_2897.jpeg
# dataset/demi plie/first position ballet_0_7381.jpeg
# dataset/demi plie/first position ballet_0_378.jpeg
# dataset/demi plie/first position ballet_0_9366.jpeg
# dataset/demi plie/first position ballet_0_6569.jpeg
# dataset/demi plie/first position ballet_0_3550.jpeg
# dataset/demi plie/first position ballet_0_9171.jpeg
# dataset/demi plie/first position ballet_0_8664.jpeg
# dataset/demi plie/first position ballet_0_6436.jpeg
# dataset/demi plie/first position ballet_0_5430.jpeg
# dataset/demi plie/first position ballet_0_3049.jpeg

# %%
class_name = "First Position"
imgs3 = []
path = "dataset/first position/"
for f in os.listdir(path):
    imgs3.append(path+f)
    
error=0
errors=[]

for i in range (77,len(imgs3)-1):
    img = cv2.imread(imgs3[i])
    #plt.figure(figsize = [10,10])
    #plt.title("Sample Image");plt.axis('off');plt.imshow(img[:,:,::-1]);plt.show()

    try:

        with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                results = holistic.process(img)
                x = len(results.pose_landmarks.landmark)

                #for i in range (0,x):
                 #   print(mp_holistic.PoseLandmark(i).name)
                 #   print(results.pose_landmarks.landmark[mp_holistic.PoseLandmark(i).value])

                pose = results.pose_landmarks.landmark
                pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
                pose_row.insert(0,class_name)

                with open('pose.csv', mode='a', newline='') as f:
                    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                    csv_writer.writerow(pose_row) 
    except AttributeError: 
                print(imgs3[i])
                error+=1
                errors.append(imgs3[i])
# Out:
# dataset/first position/first position ballet_0_4245.jpeg
# dataset/first position/first position ballet_0_5116.jpeg
# dataset/first position/first position ballet_0_1972.jpeg
# dataset/first position/first position ballet_0_8047.jpeg
# dataset/first position/first position ballet_0_2919.jpeg
# dataset/first position/first position ballet_0_609.jpeg
# dataset/first position/first position ballet_0_9210.jpeg
# dataset/first position/first position ballet_0_2959.jpeg
# dataset/first position/first position ballet_0_3348.jpeg
# dataset/first position/first position ballet_0_1230.jpeg
# dataset/first position/first position ballet_0_8441.jpeg
# dataset/first position/first position ballet_0_2918.jpeg
# dataset/first position/first position ballet_0_5418.jpeg
# dataset/first position/first position ballet_0_5434.jpeg
# dataset/first position/first position ballet_0_3630.jpeg
# dataset/first position/first position ballet_0_4399.jpeg
# dataset/first position/first position ballet_0_1898.jpeg
# dataset/first position/first position ballet_0_1174.jpeg
# dataset/first position/first position ballet_0_9821.jpeg
# dataset/first position/first position ballet_0_6185.jpeg
# dataset/first position/first position ballet_0_151.jpeg
# dataset/first position/first position ballet_0_1601.jpeg
# dataset/first position/first position ballet_0_5817.jpeg
# dataset/first position/first position ballet_0_8376.jpeg
# dataset/first position/first position ballet_0_6807.jpeg
# dataset/first position/first position ballet_0_3644.jpeg
# dataset/first position/first position ballet_0_8622.jpeg
# dataset/first position/first position ballet_0_8788.jpeg
# dataset/first position/first position ballet_0_3081.jpeg
# dataset/first position/first position ballet_0_1116.jpeg
# dataset/first position/first position ballet_0_3941.jpeg
# dataset/first position/first position ballet_0_1244.jpeg
# dataset/first position/first position ballet_0_1194.jpeg
# dataset/first position/first position ballet_0_2059.jpeg
# dataset/first position/first position ballet_0_4932.jpeg
# dataset/first position/first position ballet_0_6974.jpeg
# dataset/first position/first position ballet_0_4949.jpeg
# dataset/first position/first position ballet_0_8205.jpeg
# dataset/first position/first position ballet_0_6124.jpeg
# dataset/first position/first position ballet_0_261.jpeg
# dataset/first position/first position ballet_0_9005.jpeg
# dataset/first position/first position ballet_0_2189.jpeg
# dataset/first position/first position ballet_0_2936.jpeg
# dataset/first position/first position ballet_0_4765.jpeg
# dataset/first position/first position ballet_0_5748.jpeg
# dataset/first position/first position ballet_0_3366.jpeg
# dataset/first position/first position ballet_0_4821.jpeg
# dataset/first position/first position ballet_0_489.jpeg
# dataset/first position/first position ballet_0_8910.jpeg
# dataset/first position/first position ballet_0_1377.jpeg
# dataset/first position/first position ballet_0_3130.jpeg
# dataset/first position/first position ballet_0_4143.jpeg
# dataset/first position/first position ballet_0_2428.jpeg
# dataset/first position/first position ballet_0_6200.jpeg
# dataset/first position/first position ballet_0_2613.jpeg
# dataset/first position/first position ballet_0_4944.jpeg
# dataset/first position/first position ballet_0_6646.jpeg
# dataset/first position/first position ballet_0_3014.jpeg
# dataset/first position/first position ballet_0_5314.jpeg
# dataset/first position/first position ballet_0_850.jpeg
# dataset/first position/first position ballet_0_5482.jpeg
# dataset/first position/first position ballet_0_7846.jpeg
# dataset/first position/first position ballet_0_4657.jpeg
# dataset/first position/first position ballet_0_12.jpeg
# dataset/first position/first position ballet_0_5046.jpeg
# dataset/first position/first position ballet_0_5553.jpeg
# dataset/first position/first position ballet_0_5504.jpeg
# dataset/first position/first position ballet_0_7190.jpeg
# dataset/first position/first position ballet_0_5007.jpeg
# dataset/first position/first position ballet_0_6739.jpeg
# dataset/first position/first position ballet_0_1448.jpeg
# dataset/first position/first position ballet_0_7031.jpeg
# dataset/first position/first position ballet_0_7861.jpeg
# dataset/first position/first position ballet_0_2858.jpeg
# dataset/first position/first position ballet_0_3463.jpeg
# dataset/first position/first position ballet_0_2570.jpeg
# dataset/first position/first position ballet_0_62.jpeg
# dataset/first position/first position ballet_0_2032.jpeg
# dataset/first position/first position ballet_0_725.jpeg
# dataset/first position/first position ballet_0_2423.jpeg
# dataset/first position/first position ballet_0_2454.jpeg
# dataset/first position/first position ballet_0_3615.jpeg
# dataset/first position/first position ballet_0_251.jpeg
# dataset/first position/first position ballet_0_4892.jpeg
# dataset/first position/first position ballet_0_4191.jpeg
# dataset/first position/first position ballet_0_9961.jpeg
# dataset/first position/first position ballet_0_4386.jpeg
# dataset/first position/first position ballet_0_9799.jpeg
# dataset/first position/first position ballet_0_9777.jpeg
# dataset/first position/first position ballet_0_5611.jpeg
# dataset/first position/first position ballet_0_786.jpeg
# dataset/first position/first position ballet_0_6115.jpeg
# dataset/first position/first position ballet_0_8633.jpeg
# dataset/first position/first position ballet_0_4610.jpeg
# dataset/first position/first position ballet_0_616.jpeg
# dataset/first position/first position ballet_0_8371.jpeg
# dataset/first position/first position ballet_0_8701.jpeg
# dataset/first position/first position ballet_0_2863.jpeg
# dataset/first position/first position ballet_0_7118.jpeg
# dataset/first position/first position ballet_0_2526.jpeg
# dataset/first position/first position ballet_0_8310.jpeg
# dataset/first position/first position ballet_0_7175.jpeg
# dataset/first position/first position ballet_0_163.jpeg
# dataset/first position/first position ballet_0_8453.jpeg
# dataset/first position/first position ballet_0_476.jpeg

# %%
class_name = "Second Position"
imgs4 = []
path = "dataset/second position/"
for f in os.listdir(path):
    imgs4.append(path+f)
    
error=0
errors=[]

for i in range (77,len(imgs4)-1):
    img = cv2.imread(imgs4[i])
    #plt.figure(figsize = [10,10])
    #plt.title("Sample Image");plt.axis('off');plt.imshow(img[:,:,::-1]);plt.show()

    try:

        with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                results = holistic.process(img)
                x = len(results.pose_landmarks.landmark)

                #for i in range (0,x):
                 #   print(mp_holistic.PoseLandmark(i).name)
                 #   print(results.pose_landmarks.landmark[mp_holistic.PoseLandmark(i).value])

                pose = results.pose_landmarks.landmark
                pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
                pose_row.insert(0,class_name)

                with open('pose.csv', mode='a', newline='') as f:
                    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                    csv_writer.writerow(pose_row) 
    except AttributeError: 
                print(imgs4[i])
                error+=1
                errors.append(imgs4[i])
# Out:
# dataset/second position/first position ballet_0_2128.jpeg
# dataset/second position/first position ballet_0_3806.jpeg
# dataset/second position/first position ballet_0_2446.jpeg
# dataset/second position/first position ballet_0_1397.jpeg
# dataset/second position/first position ballet_0_7185.jpeg
# dataset/second position/first position ballet_0_7605.jpeg
# dataset/second position/first position ballet_0_2796.jpeg
# dataset/second position/first position ballet_0_5403.jpeg
# dataset/second position/first position ballet_0_9841.jpeg
# dataset/second position/first position ballet_0_9656.jpeg
# dataset/second position/first position ballet_0_824.jpeg
# dataset/second position/first position ballet_0_6624.jpeg
# dataset/second position/first position ballet_0_8378.jpeg
# dataset/second position/first position ballet_0_3758.jpeg
# dataset/second position/first position ballet_0_4423.jpeg
# dataset/second position/first position ballet_0_649.jpeg
# dataset/second position/first position ballet_0_7608.jpeg
# dataset/second position/first position ballet_0_5567.jpeg
# dataset/second position/first position ballet_0_254.jpeg
# dataset/second position/first position ballet_0_2386.jpeg
# dataset/second position/first position ballet_0_4141.jpeg
# dataset/second position/first position ballet_0_703.jpeg
# dataset/second position/first position ballet_0_7596.jpeg
# dataset/second position/first position ballet_0_2452.jpeg
# dataset/second position/first position ballet_0_3015.jpeg
# dataset/second position/first position ballet_0_410.jpeg
# dataset/second position/first position ballet_0_7555.jpeg
# dataset/second position/first position ballet_0_5138.jpeg
# dataset/second position/first position ballet_0_1086.jpeg
# dataset/second position/first position ballet_0_1340.jpeg
# dataset/second position/first position ballet_0_3392.jpeg
# dataset/second position/first position ballet_0_6893.jpeg
# dataset/second position/first position ballet_0_9357.jpeg
# dataset/second position/first position ballet_0_6630.jpeg
# dataset/second position/first position ballet_0_2018.jpeg
# dataset/second position/first position ballet_0_4820.jpeg
# dataset/second position/first position ballet_0_9984.jpeg
# dataset/second position/first position ballet_0_5964.jpeg
# dataset/second position/first position ballet_0_5708.jpeg
# dataset/second position/first position ballet_0_2218.jpeg
# dataset/second position/first position ballet_0_1530.jpeg
# dataset/second position/first position ballet_0_2465.jpeg
# dataset/second position/first position ballet_0_1635.jpeg
# dataset/second position/first position ballet_0_8286.jpeg
# dataset/second position/first position ballet_0_4285.jpeg
# dataset/second position/first position ballet_0_5986.jpeg
# dataset/second position/first position ballet_0_2412.jpeg
# dataset/second position/first position ballet_0_6514.jpeg
# dataset/second position/first position ballet_0_8043.jpeg
# dataset/second position/first position ballet_0_2823.jpeg
# dataset/second position/first position ballet_0_9280.jpeg
# dataset/second position/first position ballet_0_7656.jpeg
# dataset/second position/first position ballet_0_247.jpeg
# dataset/second position/first position ballet_0_3212.jpeg
# dataset/second position/first position ballet_0_2069.jpeg
# dataset/second position/first position ballet_0_380.jpeg
# dataset/second position/first position ballet_0_9849.jpeg
# dataset/second position/first position ballet_0_1716.jpeg
# dataset/second position/first position ballet_0_4779.jpeg
# dataset/second position/first position ballet_0_6969.jpeg
# dataset/second position/first position ballet_0_5369.jpeg
# dataset/second position/first position ballet_0_1384.jpeg
# dataset/second position/first position ballet_0_1150.jpeg
# dataset/second position/first position ballet_0_75.jpeg
# dataset/second position/first position ballet_0_1170.jpeg
# dataset/second position/first position ballet_0_2160.jpeg
# dataset/second position/first position ballet_0_7358.jpeg
# dataset/second position/first position ballet_0_7933.jpeg

# %% [markdown]
# # Data Cleaning with Pandas

# %% [markdown]
# ## 2.1 Read in Collected Data and Process

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
df = pd.read_csv('pose2.csv')

# %%
print (df.isnull().sum())
# Out:
# Class    0
# x1       0
# y1       0
# x2       0
# y2       0
#         ..
# y31      0
# x32      0
# y32      0
# x33      0
# y33      0
# Length: 67, dtype: int64

# %%
df.head()
# Out:
#              Class        x1        y1        x2        y2        x3  \
# 0  ArabesqueBallet  0.275201  0.236561  0.284344  0.221193  0.286842
# 1  ArabesqueBallet  0.753119  0.207028  0.749732  0.195578  0.749057
# 2  ArabesqueBallet  0.685356  0.147128  0.684186  0.139503  0.686391
# 3  ArabesqueBallet  0.552788  0.139511  0.556702  0.134990  0.558818
# 4  ArabesqueBallet  0.478676  0.331521  0.488061  0.329810  0.491374
#
#          y3        x4        y4        x5  ...       x29       y29       x30  \
# 0  0.221330  0.289660  0.221597  0.282060  ...  0.324232  0.933449  0.639522
# 1  0.195302  0.748312  0.195028  0.748591  ...  0.533841  0.062203  0.548960
# 2  0.138748  0.688634  0.138136  0.677711  ...  0.671119  0.729596  0.500284
# 3  0.135010  0.560927  0.135146  0.551760  ...  0.477861  0.058287  0.635258
# 4  0.331237  0.494236  0.332391  0.481541  ...  0.708762  0.418389  0.667867
#
#         y30       x31       y31       x32       y32       x33       y33
# 0  0.669630  0.332777  0.958722  0.672966  0.685053  0.303221  0.977285
# 1  0.665049  0.524292  0.049011  0.556692  0.721126  0.516863 -0.017389
# 2  0.480484  0.665011  0.752965  0.497114  0.475630  0.686222  0.767950
# 3  0.261071  0.470474  0.052482  0.637450  0.257831  0.464949  0.009118
# 4  0.571083  0.716970  0.401288  0.681788  0.578399  0.756424  0.392373
#
# [5 rows x 67 columns]

# %%
print(f'Number od rows/examples and columns in the dataset: {df.shape}')
# Out:
# Number od rows/examples and columns in the dataset: (660, 67)

# %%
#Summary of information on the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 67 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Class   660 non-null    object
#  1   x1      660 non-null    float64
#  2   y1      660 non-null    float64
#  3   x2      660 non-null    float64
#  4   y2      660 non-null    float64
#  5   x3      660 non-null    float64
#  6   y3      660 non-null    float64
#  7   x4      660 non-null    float64
#  8   y4      660 non-null    float64
#  9   x5      660 non-null    float64
#  10  y5      660 non-null    float64
#  11  x6      660 non-null    float64
#  12  y6      660 non-null    float64
#  13  x7      660 non-null    float64
#  14  y7      660 non-null    float64
#  15  x8      660 non-null    float64
#  16  y8      660 non-null    float64
#  17  x9      660 non-null    float64
#  18  y9      660 non-null    float64
#  19  x10     660 non-null    float64
#  20  y10     660 non-null    float64
#  21  x11     660 non-null    float64
#  22  y11     660 non-null    float64
#  23  x12     660 non-null    float64
#  24  y12     660 non-null    float64
#  25  x13     660 non-null    float64
#  26  y13     660 non-null    float64
#  27  x14     660 non-null    float64
#  28  y14     660 non-null    float64
#  29  x15     660 non-null    float64
#  30  y15     660 non-null    float64
#  31  x16     660 non-null    float64
#  32  y16     660 non-null    float64
#  33  x17     660 non-null    float64
#  34  y17     660 non-null    float64
#  35  x18     660 non-null    float64
#  36  y18     660 non-null    float64
#  37  x19     660 non-null    float64
#  38  y19     660 non-null    float64
#  39  x20     660 non-null    float64
#  40  y20     660 non-null    float64
#  41  x21     660 non-null    float64
#  42  y21     660 non-null    float64
#  43  x22     660 non-null    float64
#  44  y22     660 non-null    float64
#  45  x23     660 non-null    float64
#  46  y23     660 non-null    float64
#  47  x24     660 non-null    float64
#  48  y24     660 non-null    float64
#  49  x25     660 non-null    float64
#  50  y25     660 non-null    float64
#  51  x26     660 non-null    float64
#  52  y26     660 non-null    float64
#  53  x27     660 non-null    float64
#  54  y27     660 non-null    float64
#  55  x28     660 non-null    float64
#  56  y28     660 non-null    float64
#  57  x29     660 non-null    float64
#  58  y29     660 non-null    float64
#  59  x30     660 non-null    float64
#  60  y30     660 non-null    float64
#  61  x31     660 non-null    float64
#  62  y31     660 non-null    float64
#  63  x32     660 non-null    float64
#  64  y32     660 non-null    float64
#  65  x33     660 non-null    float64
#  66  y33     660 non-null    float64
# dtypes: float64(66), object(1)
# memory usage: 345.6+ KB

# %% [markdown]
# # Class Distribution - Undersampling the data

# %%
df['Class'].value_counts()
# Out:
# ArabesqueBallet    375
# Second Position    125
# Demi Plie           81
# First Position      79
# Name: Class, dtype: int64

# %%
X = df.drop('Class', axis=1) # features
y = df['Class'] # target value

# %%
#show pie plot
y.value_counts()
y.value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Class'>

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
rus = RandomUnderSampler(random_state=0)
X_resampled, y_resampled = rus.fit_resample(X,y)

ax= y_resampled.value_counts().plot.pie(autopct='%1.1f%%')
ax.set_title("Under-sampling")
# Out:
# Text(0.5, 1.0, 'Under-sampling')

# %%
y_resampled.value_counts()
# Out:
# ArabesqueBallet    79
# Demi Plie          79
# First Position     79
# Second Position    79
# Name: Class, dtype: int64

# %%
y_resampled.head()
# Out:
# 0    ArabesqueBallet
# 1    ArabesqueBallet
# 2    ArabesqueBallet
# 3    ArabesqueBallet
# 4    ArabesqueBallet
# Name: Class, dtype: object

# %%
X_resampled.head()
# Out:
#          x1        y1        x2        y2        x3        y3        x4  \
# 0  0.808785  0.603574  0.819644  0.594602  0.823010  0.596308  0.826561
# 1  0.373917  0.094154  0.388006  0.084202  0.391630  0.085298  0.396251
# 2  0.883022  0.123644  0.876498  0.111215  0.876436  0.111689  0.876206
# 3  0.503543  0.303710  0.518521  0.298000  0.523067  0.298553  0.527802
# 4  0.377383  0.157311  0.367349  0.147712  0.366813  0.147718  0.366106
#
#          y4        x5        y5  ...       x29       y29       x30       y30  \
# 0  0.598285  0.805670  0.588095  ...  0.407613  0.982520  0.558069  0.552364
# 1  0.086349  0.383942  0.082151  ...  0.773057  0.378196  0.475604  0.775657
# 2  0.112217  0.870489  0.110025  ...  0.505944  0.122174  0.438890  0.681551
# 3  0.299238  0.511184  0.298186  ...  0.784501  0.603992  0.622166  0.804509
# 4  0.147938  0.365026  0.150353  ...  0.050032  0.496779  0.384441  0.819905
#
#         x31       y31       x32       y32       x33       y33
# 0  0.402199  0.993598  0.529509  0.533156  0.310635  1.012407
# 1  0.795619  0.381453  0.454150  0.828945  0.831088  0.362683
# 2  0.504249  0.113095  0.468927  0.692348  0.500929  0.059830
# 3  0.798135  0.608925  0.584282  0.836517  0.826908  0.645737
# 4  0.045856  0.469114  0.440432  0.793459  0.018068  0.441975
#
# [5 rows x 66 columns]

# %%
new_df =X_resampled.join(y_resampled)
new_df.head()
# Out:
#          x1        y1        x2        y2        x3        y3        x4  \
# 0  0.808785  0.603574  0.819644  0.594602  0.823010  0.596308  0.826561
# 1  0.373917  0.094154  0.388006  0.084202  0.391630  0.085298  0.396251
# 2  0.883022  0.123644  0.876498  0.111215  0.876436  0.111689  0.876206
# 3  0.503543  0.303710  0.518521  0.298000  0.523067  0.298553  0.527802
# 4  0.377383  0.157311  0.367349  0.147712  0.366813  0.147718  0.366106
#
#          y4        x5        y5  ...       y29       x30       y30       x31  \
# 0  0.598285  0.805670  0.588095  ...  0.982520  0.558069  0.552364  0.402199
# 1  0.086349  0.383942  0.082151  ...  0.378196  0.475604  0.775657  0.795619
# 2  0.112217  0.870489  0.110025  ...  0.122174  0.438890  0.681551  0.504249
# 3  0.299238  0.511184  0.298186  ...  0.603992  0.622166  0.804509  0.798135
# 4  0.147938  0.365026  0.150353  ...  0.496779  0.384441  0.819905  0.045856
#
#         y31       x32       y32       x33       y33            Class
# 0  0.993598  0.529509  0.533156  0.310635  1.012407  ArabesqueBallet
# 1  0.381453  0.454150  0.828945  0.831088  0.362683  ArabesqueBallet
# 2  0.113095  0.468927  0.692348  0.500929  0.059830  ArabesqueBallet
# 3  0.608925  0.584282  0.836517  0.826908  0.645737  ArabesqueBallet
# 4  0.469114  0.440432  0.793459  0.018068  0.441975  ArabesqueBallet
#
# [5 rows x 67 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 7      ArabesqueBallet
# 40     ArabesqueBallet
# 284    Second Position
# 190     First Position
# 37     ArabesqueBallet
#             ...
# 259    Second Position
# 5      ArabesqueBallet
# 164     First Position
# 255    Second Position
# 299    Second Position
# Name: Class, Length: 95, dtype: object

# %% [markdown]
# ## 2.2 Train ML Classification Model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn import svm
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
    'svc':make_pipeline(StandardScaler(),SVC(kernel='rbf'))
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# /usr/local/Cellar/jupyterlab/3.1.14/libexec/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())]),
#  'svc': Pipeline(steps=[('standardscaler', StandardScaler()), ('svc', SVC())])}

# %%
fit_models['svc'].predict(X_test) #test to see if it works
# Out:
# array(['ArabesqueBallet', 'ArabesqueBallet', 'Demi Plie',
#        'First Position', 'ArabesqueBallet', 'Second Position',
#        'First Position', 'Second Position', 'Second Position',
#        'ArabesqueBallet', 'Second Position', 'Second Position',
#        'ArabesqueBallet', 'Demi Plie', 'Second Position',
#        'ArabesqueBallet', 'ArabesqueBallet', 'First Position',
#        'Second Position', 'ArabesqueBallet', 'First Position',
#        'Demi Plie', 'Demi Plie', 'Demi Plie', 'Demi Plie',
#        'Second Position', 'ArabesqueBallet', 'Demi Plie', 'Demi Plie',
#        'Demi Plie', 'Second Position', 'ArabesqueBallet',
#        'Second Position', 'First Position', 'Second Position',
#        'First Position', 'Second Position', 'Second Position',
#        'First Position', 'Demi Plie', 'First Position', 'ArabesqueBallet',
#        'ArabesqueBallet', 'ArabesqueBallet', 'Demi Plie',
#        'First Position', 'First Position', 'ArabesqueBallet', 'Demi Plie',
#        'First Position', 'ArabesqueBallet', 'First Position',
#        'First Position', 'ArabesqueBallet', 'ArabesqueBallet',
#        'ArabesqueBallet', 'Demi Plie', 'Second Position', 'Demi Plie',
#        'First Position', 'Second Position', 'First Position',
#        'First Position', 'ArabesqueBallet', 'ArabesqueBallet',
#        'ArabesqueBallet', 'First Position', 'First Position',
#        'ArabesqueBallet', 'First Position', 'Demi Plie',
#        'Second Position', 'ArabesqueBallet', 'Second Position',
#        'Demi Plie', 'First Position', 'First Position', 'ArabesqueBallet',
#        'Demi Plie', 'ArabesqueBallet', 'ArabesqueBallet',
#        'Second Position', 'Demi Plie', 'First Position',
#        'Second Position', 'First Position', 'First Position',
#        'First Position', 'Second Position', 'First Position',
#        'Second Position', 'ArabesqueBallet', 'First Position',
#        'Second Position', 'Second Position'], dtype=object)

# %% [markdown]
# ## 2.3 Evaluate and serial model

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 0.7789473684210526
# rc 0.8210526315789474
# rf 0.6842105263157895
# gb 0.6842105263157895
# svc 0.6842105263157895

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['ArabesqueBallet', 'ArabesqueBallet', 'Second Position',
#        'First Position', 'ArabesqueBallet', 'ArabesqueBallet',
#        'First Position', 'Second Position', 'Second Position',
#        'First Position', 'Second Position', 'Demi Plie',
#        'ArabesqueBallet', 'First Position', 'Second Position',
#        'ArabesqueBallet', 'First Position', 'First Position',
#        'Second Position', 'ArabesqueBallet', 'Demi Plie',
#        'Second Position', 'Demi Plie', 'Second Position', 'Demi Plie',
#        'First Position', 'ArabesqueBallet', 'Demi Plie',
#        'Second Position', 'Second Position', 'Second Position',
#        'Second Position', 'Demi Plie', 'Demi Plie', 'Second Position',
#        'ArabesqueBallet', 'Second Position', 'Second Position',
#        'First Position', 'Demi Plie', 'First Position', 'ArabesqueBallet',
#        'ArabesqueBallet', 'First Position', 'Demi Plie', 'First Position',
#        'First Position', 'ArabesqueBallet', 'Second Position',
#        'First Position', 'Demi Plie', 'First Position', 'Demi Plie',
#        'ArabesqueBallet', 'First Position', 'Demi Plie',
#        'Second Position', 'Second Position', 'Second Position',
#        'First Position', 'Second Position', 'First Position',
#        'First Position', 'Second Position', 'Demi Plie',
#        'ArabesqueBallet', 'Demi Plie', 'First Position',
#        'ArabesqueBallet', 'Second Position', 'Second Position',
#        'Second Position', 'ArabesqueBallet', 'Second Position',
#        'First Position', 'First Position', 'First Position',
#        'ArabesqueBallet', 'Demi Plie', 'ArabesqueBallet',
#        'ArabesqueBallet', 'Second Position', 'Second Position',
#        'First Position', 'Demi Plie', 'First Position', 'First Position',
#        'First Position', 'Second Position', 'First Position',
#        'Second Position', 'ArabesqueBallet', 'First Position',
#        'Second Position', 'Second Position'], dtype='<U15')

# %%
y_test
# Out:
# 7      ArabesqueBallet
# 40     ArabesqueBallet
# 284    Second Position
# 190     First Position
# 37     ArabesqueBallet
#             ...
# 259    Second Position
# 5      ArabesqueBallet
# 164     First Position
# 255    Second Position
# 299    Second Position
# Name: Class, Length: 95, dtype: object

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rc'], f)

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('ridgeclassifier', RidgeClassifier())])

# %%
cap = cv2.VideoCapture(0)
# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    while cap.isOpened():
        ret, frame = cap.read()
        
        # Recolor Feed
        image = cv2.flip(frame,1)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        
        # Make Detections
        results = holistic.process(image)
        # print(results.face_landmarks)
        
        # face_landmarks, pose_landmarks, left_hand_landmarks, right_hand_landmarks
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # 4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS, 
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                 )
        # Export coordinates
        try:
            # Extract Pose landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())
            
            # Make Detections
            X = pd.DataFrame([pose_row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)
            
            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            
            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
        except:
            pass
                        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6r/pshzd_g91x507c9clx9pdgyh0000gn/T/ipykernel_1222/4022986322.py in <module>
#       1 cap = cv2.VideoCapture(0)
#       2 # Initiate holistic model
# ----> 3 with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
#       4
#       5     while cap.isOpened():
#
# NameError: name 'mp_holistic' is not defined
